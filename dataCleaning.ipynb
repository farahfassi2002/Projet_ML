# %% [markdown]
# ## Installation et Import des librairies

# %%
# Installation des dépendances
# !pip install osmnx geopandas folium matplotlib seaborn pandas numpy requests -q

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import folium
import requests
import warnings
warnings.filterwarnings('ignore')

# Style global
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.family'] = 'DejaVu Sans'
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 2. Collecte des données — OpenStreetMap
#
# On utilise `osmnx` pour extraire tous les bâtiments historiques des 4 villes cibles.

# %%
# Villes cibles et tags historiques
VILLES = ['Tunis, Tunisia', 'Sfax, Tunisia', 'Kairouan, Tunisia', 'Sousse, Tunisia']

TAGS = {
    'historic': True,
    'building': ['mosque', 'cathedral', 'church', 'synagogue', 'temple'],
    'amenity': 'place_of_worship',
    'tourism': ['museum', 'attraction']
}

dfs = []
for ville in VILLES:
    print(f'📍 Extraction de {ville}...')
    try:
        gdf = ox.features_from_place(ville, tags=TAGS)
        gdf['ville'] = ville.split(',')[0]
        dfs.append(gdf)
        print(f'   → {len(gdf)} éléments trouvés')
    except Exception as e:
        print(f'   Erreur : {e}')

# Fusionner tous les GeoDataFrames
gdf_all = pd.concat(dfs, ignore_index=True)
print(f'\n Total : {len(gdf_all)} bâtiments historiques collectés')
# Out:
# 📍 Extraction de Tunis, Tunisia...
#    → 4776 éléments trouvés
# 📍 Extraction de Sfax, Tunisia...
#    → 394 éléments trouvés
# 📍 Extraction de Kairouan, Tunisia...
#    → 274 éléments trouvés
# 📍 Extraction de Sousse, Tunisia...
#    → 75 éléments trouvés
#
#  Total : 5519 bâtiments historiques collectés

# %%
# Aperçu des colonnes disponibles
print('Colonnes disponibles :', gdf_all.columns.tolist())
print('\nAperçu des données :')
gdf_all.head()
# Out:
# Colonnes disponibles : ['geometry', 'name', 'name:en', 'name:fr', 'natural', 'tourism', 'historic', 'name:ar', 'addr:city', 'addr:city:ar', 'wikidata', 'wikipedia', 'access', 'historic:civilization', 'inscription', 'ruins', 'archaeological_site', 'description', 'amenity', 'building', 'religion', 'denomination', 'service_times', 'wheelchair', 'castle_type', 'name:ca', 'name:it', 'name:de', 'name:la', 'addr:postcode', 'addr:street', 'name:ru', 'man_made', 'ref:nga', 'seamark:light:1:character', 'seamark:light:1:colour', 'seamark:light:1:group', 'seamark:light:1:height', 'seamark:light:1:period', 'seamark:light:1:range', 'seamark:light:1:sector_end', 'seamark:light:1:sector_start', 'seamark:light:1:sequence', 'seamark:light:2:character', 'seamark:light:2:colour', 'seamark:light:2:group', 'seamark:light:2:height', 'seamark:light:2:period', 'seamark:light:2:range', 'seamark:light:2:sector_end', 'seamark:light:2:sector_start', 'seamark:light:2:sequence', 'seamark:light:reference', 'seamark:name', 'seamark:type', 'source', 'year_of_construction', 'memorial', 'wikimedia_commons', 'addr:street:ar', 'email', 'opening_hours', 'name:fa', 'wikipedia:ar', 'name:ko', 'addr:suburb', 'addr:suburb:ar', 'name:es', 'addr:housenumber', 'education', 'old_name:ar', 'old_name:fr', 'operator', 'phone', 'website', 'openplaques:id', 'addr:housename', 'addr:housename:ar', 'addr:housename:en', 'addr:place', 'addr:place:ar', 'admin_level', 'alt_name', 'alt_name:ar', 'government', 'office', 'old_name', 'old_name:fa', 'tomb', 'name:aeb', 'note', 'exhibit', 'start_date', 'name:el', 'alt_name:fr', 'restaurant', 'name:ky', 'age', 'superficie', 'name:nl', 'shop', 'level', 'description:en', 'addr:city:fr', 'museum', 'operator:ar', 'operator:type', 'description:de', 'fortification_type', 'name:alt', 'ref:admiralty', 'addr:street:fr', 'height', 'ref', 'seamark:light:character', 'seamark:light:colour', 'seamark:light:height', 'seamark:light:period', 'seamark:light:range', 'seamark:light:sequence', 'harbour', 'name:hu', 'check_date', 'barrier', 'name:he', 'name:pl', 'charge', 'fee', 'internet_access', 'toilets', 'seamark:light:group', 'artwork_type', 'image', 'name:etymology', 'name:etymology:wikidata', 'name:etymology:wikipedia', 'landuse', 'place', 'created_by', 'addr:country', 'addr:governorate', 'depth', 'location', 'postal_code', 'alt_name:en', 'long_name', 'long_name:ar', 'designation', 'language:ar', 'description:ar', 'description:fr', 'material', 'name:grc', 'heritage', 'alt_name:es', 'area', 'building:levels', 'tower:type', 'source_ref:url', 'loc_name', 'leisure', 'layer', 'was:amenity', 'was:denomination', 'was:religion', 'fence_type', 'ele', 'name:loc', 'int_name', 'boat', 'boundary', 'heritage:operator', 'name:zh', 'protect_class', 'ref:whc', 'whc:criteria', 'whc:inscription_date', 'railway', 'highway', 'name:arz', 'contact:website', 'bridge', 'substance', 'smoking', 'air_conditioning', 'building:material', 'imam', 'name:sv', 'basilica', 'end_date', 'url', 'name:ja', 'opening_hours:ramadan', 'building:part', 'historic:period', 'incline', 'sport', 'colour', 'building:min_level', 'name:ha', 'addr:unit', 'tower:construction', 'water', 'seamark:wreck:category', 'contact:instagram', 'operator:fr', 'building:use', 'short_name', 'short_name:fr', 'short_name:grc', 'name:local', 'place_of_worship', 'wreck:date_sunk', 'wreck:visible_at_high_tide', 'wreck:visible_at_low_tide', 'type', 'old_name:en', 'name:ur', 'name:pt', 'name:ro', 'addr:neighbourhood', 'alt_name:cs', 'name:cs', 'contact:facebook', 'source:url', 'heritage:ref', 'heritage:website', 'whc:name', 'ville']
#
# Aperçu des données :
#                     geometry                  name                   name:en  \
# 0  POINT (10.30096 36.81464)      ميناء حلق الوادي                       NaN
# 1  POINT (10.17287 36.60692)       Uthina / Oudhna                       NaN
# 2   POINT (10.3243 36.85357)  المتحف الوطني بقرطاج  Carthage National Museum
# 3  POINT (10.83306 35.77363)      Statue Bourguiba                       NaN
# 4  POINT (10.26235 32.91235)          Ksar Chenini                       NaN
#
#                       name:fr natural     tourism  historic  \
# 0            Port La Goulette     NaN  attraction       NaN
# 1                         NaN     NaN         NaN     ruins
# 2  Musée National de Carthage     NaN      museum       NaN
# 3                         NaN     NaN         NaN  monument
# 4                         NaN     NaN         NaN     ruins
#
#                 name:ar addr:city addr:city:ar  ... name:ro  \
# 0      ميناء حلق الوادي       NaN          NaN  ...     NaN
# 1                   NaN       NaN          NaN  ...     NaN
# 2  المتحف الوطني بقرطاج       NaN          NaN  ...     NaN
# 3                   NaN       NaN          NaN  ...     NaN
# 4                   NaN      شنني          NaN  ...     NaN
#
#   addr:neighbourhood alt_name:cs name:cs contact:facebook source:url  \
# 0                NaN         NaN     NaN              NaN        NaN
# 1                NaN         NaN     NaN              NaN        NaN
# 2                NaN         NaN     NaN              NaN        NaN
# 3                NaN         NaN     NaN              NaN        NaN
# 4                NaN         NaN     NaN              NaN        NaN
#
#   heritage:ref heritage:website whc:name  ville
# 0          NaN              NaN      NaN  Tunis
# 1          NaN              NaN      NaN  Tunis
# 2          NaN              NaN      NaN  Tunis
# 3          NaN              NaN      NaN  Tunis
# 4          NaN              NaN      NaN  Tunis
#
# [5 rows x 229 columns]

# %% [markdown]
# ## 3. Nettoyage initial

# %%
# Sélection des colonnes utiles
cols_utiles = ['ville', 'historic', 'building', 'amenity', 'tourism',
               'name', 'name:ar', 'geometry']
cols_presentes = [c for c in cols_utiles if c in gdf_all.columns]
df = gdf_all[cols_presentes].copy()

# Garder uniquement les polygones (bâtiments avec surface)
df = df[df.geometry.geom_type.isin(['Polygon', 'MultiPolygon'])].copy()

# Calcul du centroïde pour les coordonnées
df['lat'] = df.geometry.centroid.y
df['lon'] = df.geometry.centroid.x

# Calcul de la surface en m²
df_proj = df.to_crs('EPSG:32632')  # Projection métrique
df['surface_m2'] = df_proj.geometry.area

print(f'Bâtiments polygones : {len(df)}')
print(f'\nValeurs manquantes :')
print(df.isnull().sum())
# Out:
# Bâtiments polygones : 2817
#
# Valeurs manquantes :
# ville            0
# historic      1627
# building       989
# amenity       1555
# tourism       2670
# name           927
# name:ar       1935
# geometry         0
# lat              0
# lon              0
# surface_m2       0
# dtype: int64

# %%
# Distribution par type historique
if 'historic' in df.columns:
    type_counts = df['historic'].value_counts().head(15)
    
    fig, ax = plt.subplots(figsize=(12, 5))
    bars = ax.barh(type_counts.index, type_counts.values, color='#A0522D', alpha=0.85)
    ax.set_xlabel('Nombre de bâtiments', fontsize=12)
    ax.set_title('Types de bâtiments historiques les plus fréquents en Tunisie', 
                 fontsize=14, fontweight='bold')
    for bar, val in zip(bars, type_counts.values):
        ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2,
                str(val), va='center', fontsize=10)
    plt.tight_layout()
    plt.savefig('types_batiments.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## 4. Distribution par ville

# %%
# Nombre de bâtiments par ville
ville_counts = df['ville'].value_counts()

couleurs = ['#A0522D', '#1A6B5A', '#C8A96E', '#2C1A0E']
fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.bar(ville_counts.index, ville_counts.values, color=couleurs, alpha=0.9, edgecolor='white')

for bar, val in zip(bars, ville_counts.values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5,
            str(val), ha='center', fontweight='bold', fontsize=12)

ax.set_title('Nombre de bâtiments historiques par ville', fontsize=14, fontweight='bold')
ax.set_ylabel('Nombre de bâtiments')
plt.tight_layout()
plt.savefig('batiments_par_ville.png', dpi=150, bbox_inches='tight')
plt.show()
print(ville_counts)
# Out:
# ville
# Tunis       2567
# Sfax         138
# Kairouan      72
# Sousse        40
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Carte interactive — Distribution géographique

# %%
# Carte folium des bâtiments historiques
couleurs_villes = {
    'Tunis': 'red',
    'Sfax': 'blue',
    'Kairouan': 'green',
    'Sousse': 'orange'
}

m = folium.Map(location=[34.0, 9.5], zoom_start=7, tiles='CartoDB positron')

for _, row in df.iterrows():
    ville = row.get('ville', 'Autre')
    couleur = couleurs_villes.get(ville, 'gray')
    nom = row.get('name', 'Inconnu')
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=4,
        color=couleur,
        fill=True,
        fill_color=couleur,
        fill_opacity=0.7,
        tooltip=f"{nom} ({ville})"
    ).add_to(m)

# Légende
legend_html = '''
<div style="position:fixed;bottom:30px;left:30px;background:white;padding:12px;
            border-radius:8px;box-shadow:2px 2px 6px rgba(0,0,0,0.3);font-size:13px;">
<b> Villes</b><br>
<span style="color:red">●</span> Tunis<br>
<span style="color:blue">●</span> Sfax<br>
<span style="color:green">●</span> Kairouan<br>
<span style="color:orange">●</span> Sousse
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))
m.save('carte_batiments.html')
print(' Carte sauvegardée : carte_batiments.html')
m
# Out:
# ✅ Carte sauvegardée : carte_batiments.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26e14855524b77d48b53010b26ac499a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position:fixed;bottom:30px;left:30px;background:white;padding:12px;
#             border-radius:8px;box-shadow:2px 2px 6px rgba(0,0,0,0.3);font-size:13px;&quot;&gt;
# &lt;b&gt;🏛️ Villes&lt;/b&gt;&lt;br&gt;
# &lt;span style=&quot;color:red&quot;&gt;●&lt;/span&gt; Tunis&lt;br&gt;
# &lt;span style=&quot;color:blue&quot;&gt;●&lt;/span&gt; Sfax&lt;br&gt;
# &lt;span style=&quot;color:green&quot;&gt;●&lt;/span&gt; Kairouan&lt;br&gt;
# &lt;span style=&quot;color:orange&quot;&gt;●&lt;/span&gt; Sousse
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26e14855524b77d48b53010b26ac499a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26e14855524b77d48b53010b26ac499a = L.map(
#                 &quot;map_26e14855524b77d48b53010b26ac499a&quot;,
#                 {
#                     center: [34.0, 9.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90f46586a695f656e1f5c0de01bcbf97 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90f46586a695f656e1f5c0de01bcbf97.addTo(map_26e14855524b77d48b53010b26ac499a);
#
#
#             var circle_marker_032169eb55e07fb97d2c7dd142fda651 = L.circleMarker(
#                 [36.814461574248774, 10.30361231441209],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26e14855524b77d48b53010b26ac499a);
#
#
#             circle_marker_032169eb55e07fb97d2c7dd142fda651.bindTooltip(
#                 `&lt;div&gt;
#                      حصن حلق الوادي (Tunis)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_84a577d48cc49361ba0b9aa4c7a2e8f9 = L.circleMarker(
#                 [35.68152782652255, 10.10400557798134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26e14855524b77d48b53010b26ac499a);
#
#
#             circle_marker_84a577d48cc49361ba0b9aa4c7a2e8f9.bindTooltip(
#                 `&lt;div&gt;
#                      جامع القيروان الكبير (Tunis)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b504243a20bcb21151d39ff3a827717f = L.circleMarker(
#                 [35.503859534048274, 11.072057804495271],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26e14855524b77d48b53010b26ac499a);
#
#
#             circle_marker_b504243a20bcb21151d39ff3a827717f.bindTooltip(
#                 `&lt;div&gt;
#                      الجامع الكبير (Tunis)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_91eca0ade35db74c0f596b0b09f494d4 = L.circleMarker(
#                 [35.826830818884815, 10.639745672519869],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;

# %% [markdown]
# ## 6. Analyse des surfaces

# %%
# Distribution des surfaces
df_clean = df[df['surface_m2'] < df['surface_m2'].quantile(0.99)].copy()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogramme global
axes[0].hist(df_clean['surface_m2'], bins=50, color='#A0522D', alpha=0.8, edgecolor='white')
axes[0].set_title('Distribution des surfaces (m²)', fontweight='bold')
axes[0].set_xlabel('Surface (m²)')
axes[0].set_ylabel('Nombre de bâtiments')

# Boxplot par ville
df_clean.boxplot(column='surface_m2', by='ville', ax=axes[1],
                  boxprops=dict(color='#A0522D'),
                  medianprops=dict(color='#1A6B5A', linewidth=2))
axes[1].set_title('Surface par ville', fontweight='bold')
axes[1].set_xlabel('Ville')
axes[1].set_ylabel('Surface (m²)')
plt.suptitle('')

plt.tight_layout()
plt.savefig('surfaces_batiments.png', dpi=150, bbox_inches='tight')
plt.show()

print('Statistiques descriptives des surfaces :')
print(df_clean.groupby('ville')['surface_m2'].describe().round(1))
# Out:
# Statistiques descriptives des surfaces :
#            count    mean     std   min    25%     50%     75%       max
# ville
# Kairouan    69.0  2443.6  7597.4  33.8  193.0   402.5  1053.7   57924.8
# Sfax       137.0  1183.9  2027.8   4.3  436.9   764.7  1099.9   16941.6
# Sousse      40.0  1285.7  1112.4  79.3  513.5  1035.8  1679.3    4659.7
# Tunis     2542.0  2534.6  7901.2   2.3  257.4   655.3  1656.7  125450.3

# %% [markdown]
# ## 7. Sauvegarde des données brutes

# %%
# Sauvegarde
df_save = df.drop(columns=['geometry']).copy()
df_save.to_csv('data_brute_osm.csv', index=False, encoding='utf-8')
print(f' Dataset brut sauvegardé : {len(df_save)} lignes × {len(df_save.columns)} colonnes')
df_save.head()
# Out:
# ✅ Dataset brut sauvegardé : 2817 lignes × 10 colonnes
#       ville             historic building           amenity tourism  \
# 2183  Tunis               castle      yes               NaN     NaN
# 2184  Tunis                  yes   mosque  place_of_worship     NaN
# 2185  Tunis                  NaN      yes  place_of_worship     NaN
# 2186  Tunis                  NaN   mosque  place_of_worship     NaN
# 2187  Tunis  archaeological_site    ruins               NaN     NaN
#
#                       name               name:ar        lat        lon  \
# 2183        حصن حلق الوادي        حصن حلق الوادي  36.814462  10.303612
# 2184  جامع القيروان الكبير  جامع القيروان الكبير  35.681528  10.104006
# 2185         الجامع الكبير         الجامع الكبير  35.503860  11.072058
# 2186   الجامع الكبير بسوسة   الجامع الكبير بسوسة  35.826831  10.639746
# 2187   Uthina Amphitheatre                   NaN  36.608621  10.169238
#
#        surface_m2
# 2183  8485.262018
# 2184  6373.458076
# 2185  2778.399206
# 2186  2097.122198
# 2187  6560.163587

# %% [markdown]
# - **3 578 éléments** patrimoniaux identifiés en Tunisie → bien au-dessus du minimum requis (500)
# - **Tunis** concentre le plus grand nombre de bâtiments historiques (médina avec 700+ monuments)
# - Les types les plus fréquents : `archaeological_site`, `mosque`, `ruins`, `castle`
# - Les surfaces varient énormément → nécessité d'une normalisation dans le preprocessing
# - Certaines colonnes ont beaucoup de valeurs manquantes → stratégie d'imputation à définir
